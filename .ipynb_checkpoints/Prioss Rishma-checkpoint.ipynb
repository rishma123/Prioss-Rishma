# %%
import json
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt
import folium
import pandas as pd

# %%
with open('loginsample.json', 'r') as json_file:
	json_load = json.load(json_file)
data = pd.DataFrame(json_load['account_activity'])

# %%
data["lat"] = ""
data["long"] = ""

# %%
for index,row in data.iterrows():
    Nomi_locator = Nominatim(user_agent=row['user_agent'])
    location = Nomi_locator.geocode(row['city'])
    data.at[index,"lat"] = location.latitude
    data.at[index,"long"] = location.longitude

# %%
m = folium.Map(location=[51.1657,10.4515], tiles="OpenStreetMap", zoom_start=6)
for index,row in data.iterrows():
    pop += "<b>City</b>:" +row['city'] + "<br>"
    pop += "<b>Date</b>:"+str(row['timestamp']) + "<br>"
    pop += "<b>Site name</b>:"+row['site_name']+ "<br>"
    pop = "<b>IP address</b> : "+row['ip_address'] + "<br>"
    pop += "<b>Action</b>: "+row['action'] + "<br>"
   
    pop = folium.Popup(folium.IFrame(pop),min_width=300,max_width=350)
    folium.Marker(
      location=[row['lat'], row['long']],
      popup=pop,
   ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e01d1d566fb3ee859ec670a7e9d98c7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e01d1d566fb3ee859ec670a7e9d98c7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_e01d1d566fb3ee859ec670a7e9d98c7a = L.map(
#                 &quot;map_e01d1d566fb3ee859ec670a7e9d98c7a&quot;,
#                 {
#                     center: [51.1657, 10.4515],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67b050151dd243bc5b317c8b69300559 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e01d1d566fb3ee859ec670a7e9d98c7a);
#
#
#             var marker_2c5f289e25b7b43222e691107baaf3db = L.marker(
#                 [52.5170365, 13.3888599],
#                 {}
#             ).addTo(map_e01d1d566fb3ee859ec670a7e9d98c7a);
#
#
#         var popup_ada290813eeab0794370ee2384b3a877 = L.popup({&quot;maxWidth&quot;: 350, &quot;minWidth&quot;: 300});
#
#
#             var i_frame_b47a55e4a380c5453162a17c77ec2028 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5JUCBhZHJlc3M8L2I+IDogMTMxLjIzNy4yNDEuODg8YnI+PGI+QWN0aW9uPC9iPjogU2Vzc2lvbiB1cGRhdGVkPGJyPjxiPkNpdHk8L2I+OkJlcmxpbjxicj48Yj5EYXRlPC9iPjoxNjUxMzcyMjMwPGJyPjxiPlNpdGUgbmFtZTwvYj46d3d3LmZhY2Vib29rLmNvbTxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_ada290813eeab0794370ee2384b3a877.setContent(i_frame_b47a55e4a380c5453162a17c77ec2028);
#
#
#         marker_2c5f289e25b7b43222e691107baaf3db.bindPopup(popup_ada290813eeab0794370ee2384b3a877)
#         ;
#
#
#
#
#             var marker_ae80205b76e9b0168d412d60532d4416 = L.marker(
#                 [53.550341, 10.000654],
#                 {}
#             ).addTo(map_e01d1d566fb3ee859ec670a7e9d98c7a);
#
#
#         var popup_b5faaa313a863f5fdb71348a61a2301d = L.popup({&quot;maxWidth&quot;: 350, &quot;minWidth&quot;: 300});
#
#
#             var i_frame_fe550b6ee4a4048032070def2e66e3fd = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5JUCBhZHJlc3M8L2I+IDogMTM3LjIwMS41MzkuODU8YnI+PGI+QWN0aW9uPC9iPjogTG9naW48YnI+PGI+Q2l0eTwvYj46SGFtYnVyZzxicj48Yj5EYXRlPC9iPjoxNjU3ODE4MTQzPGJyPjxiPlNpdGUgbmFtZTwvYj46d3d3LmZhY2Vib29rLmNvbTxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_b5faaa313a863f5fdb71348a61a2301d.setContent(i_frame_fe550b6ee4a4048032070def2e66e3fd);
#
#
#         marker_ae80205b76e9b0168d412d60532d4416.bindPopup(popup_b5faaa313a863f5fdb71348a61a2301d)
#         ;
#
#
#
#
#             var marker_1437d624dc8320cec40fb0c1a8696671 = L.marker(
#                 [51.71895955, 8.764869778177559],
#                 {}
#             ).addTo(map_e01d1d566fb3ee859ec670a7e9d98c7a);
#
#
#         var popup_4f51b0bd731c68ae6f54a5ca1ff94c96 = L.popup({&quot;maxWidth&quot;: 350, &quot;minWidth&quot;: 300});
#
#
#             var i_frame_12b11e7da5f447b02341a4fd8681b543 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5JUCBhZHJlc3M8L2I+IDogMTA4LjU1My4yMzguNjQ8YnI+PGI+QWN0aW9uPC9iPjogU2Vzc2lvbiB1cGRhdGVkPGJyPjxiPkNpdHk8L2I+OlBhZGVyYm9ybjxicj48Yj5EYXRlPC9iPjoxNjU1NzIwOTc1PGJyPjxiPlNpdGUgbmFtZTwvYj46d3d3LmZhY2Vib29rLmNvbTxicj4=&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#             popup_4f51b0bd731c68ae6f54a5ca1ff94c96.setContent(i_frame_12b11e7da5f447b02341a4fd8681b543);
#
#
#         marker_1437d624dc8320cec40fb0c1a8696671.bindPopup(popup_4f51b0bd731c68ae6f54a5ca1ff94c96)
#         ;
#
#
#
#
#             var marker_7599b5eb98b2e890f7b4960ffb521527 = L.marker(
#                 [51.71895955, 8.764869778177559],
#                 {}
#             ).addTo(map_e01d1d566fb3ee859ec670a7e9d98c7a);
#
#
#         var popup_574431901620e979271ecbcaff74975c = L.popup({&quot;maxWidth&quot;: 350, &quot;minWidth&quot;: 300});
#
#
#             var i_frame_91d8e62ab7e405c6f656d8fcd256f1c7 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5JUCBhZHJlc3M8L2I+IDogMTA4LjU1My4yMzguNjQ8YnI+PGI+QWN0aW9uPC9iPjogU2Vz
